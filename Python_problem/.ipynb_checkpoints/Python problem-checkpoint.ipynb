# %% [markdown]
# ## Problem statement
# You have to write a python script which can fetch all the tweets(as many as allowed by Twitter
# API) done by [midas@IIITD](https://twitter.com/midasIIITD) twitter handle and dump the responses into JSONlines file.
# The other part of your script should be able to parse these JSONline files to display the
# following for every tweet in a tabular format.
# * The text of the tweet.
# * Date and time of the tweet.
# * The number of favorites/likes.
# * The number of retweets.
# * Number of Images present in Tweet. If no image returns None.

# %% [markdown]
# ### Imports

# %%
import tweepy
from tweepy import OAuthHandler
import json
import os
import pandas as pd
from datetime import datetime

# %%
#Path for JSON file
FILE_PATH = os.path.join(os.getcwd(), "/Users/Akshay/Desktop/tweets.json")

# %% [markdown]
# ### Authorization

# %%
ACCESS_TOKEN = "#"
ACCESS_TOKEN_SECRET = "#"
CONSUMER_KEY = "#" 
CONSUMER_SECRET_KEY = "#"

# %%
auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET_KEY)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %% [markdown]
# ## First Part - Fetch Tweets and Dump them into JSON Line file

# %%
def fetch_and_dump_tweets(screen_name):
    '''
    screen_name: Twitter handle of the user
    tweets: List (of length 200) of tweets
    all_tweets: List of all tweets
    oldest: Index of oldest fetched tweet
    '''
    
    all_tweets = []
    tweets = api.user_timeline(screen_name = screen_name,count=200)
    all_tweets.extend(tweets)
    oldest = all_tweets[-1].id - 1
    
    while len(tweets) > 0:
        tweets = api.user_timeline(screen_name = screen_name, count=200, max_id=oldest)
        all_tweets.extend(tweets)
        oldest = all_tweets[-1].id - 1

    print(f"Total number of tweets from {screen_name} are {len(all_tweets)}")
    
    all_tweets_json = []
    for tweet in all_tweets:
        all_tweets_json.append(tweet._json)
    with open(FILE_PATH, 'w', encoding='utf8') as f:
        json.dump(all_tweets_json, f, sort_keys = True,indent = 4)
    return all_tweets

# %%
tweets_by_MIDAS = fetch_and_dump_tweets("midasIIITD")
# Out:
# Total number of tweets from midasIIITD are 294

# %%
with open(FILE_PATH) as json_file:  
    tweets_by_MIDAS = json.load(json_file)

# %%
tweets_by_MIDAS[10]['entities']
# Out:
# {'hashtags': [],
#  'symbols': [],
#  'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#    'expanded_url': 'https://twitter.com/i/web/status/1105478029147553792',
#    'indices': [110, 133],
#    'url': 'https://t.co/XEkcYO8KmW'}],
#  'user_mentions': [{'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'indices': [23, 34],
#    'name': 'MIDAS IIITD',
#    'screen_name': 'midasIIITD'}]}

# %%
def fetch_and_dump_tweets(screen_name):
    '''
    screen_name: Twitter handle of the user
    tweets: List (of length 200) of tweets
    all_tweets: List of all tweets
    oldest: Index of oldest fetched tweet
    '''
    
    all_tweets = []
    tweets = api.user_timeline(screen_name = screen_name,count=200, tweet_mode = 'extended')
    all_tweets.extend(tweets)
    oldest = all_tweets[-1].id - 1
    
    while len(tweets) > 0:
        tweets = api.user_timeline(screen_name = screen_name, count=200, max_id=oldest, tweet_mode = 'extended')
        all_tweets.extend(tweets)
        oldest = all_tweets[-1].id - 1

    print(f"Total number of tweets from {screen_name} are {len(all_tweets)}")
    
    all_tweets_json = []
    for tweet in all_tweets:
        all_tweets_json.append(tweet._json)
    with open(FILE_PATH, 'w', encoding='utf8') as f:
        json.dump(all_tweets_json, f, sort_keys = True,indent = 4)
    return all_tweets

# %%
tweets_by_MIDAS = fetch_and_dump_tweets("midasIIITD")
# Out:
# Total number of tweets from midasIIITD are 294

# %%
with open(FILE_PATH) as json_file:  
    tweets_by_MIDAS = json.load(json_file)

# %%
tweets_by_MIDAS[10]['entities']
# Out:
# {'hashtags': [{'indices': [111, 116], 'text': 'team'},
#   {'indices': [117, 126], 'text': 'research'},
#   {'indices': [127, 130], 'text': 'AI'},
#   {'indices': [131, 134], 'text': 'ML'},
#   {'indices': [135, 144], 'text': 'projects'}],
#  'media': [{'display_url': 'pic.twitter.com/lN7hItwPO9',
#    'expanded_url': 'https://twitter.com/midasIIITD/status/1105478029147553792/photo/1',
#    'id': 1105477322264772610,
#    'id_str': '1105477322264772610',
#    'indices': [145, 168],
#    'media_url': 'http://pbs.twimg.com/media/D1dxxHzXgAIeNSE.jpg',
#    'media_url_https': 'https://pbs.twimg.com/media/D1dxxHzXgAIeNSE.jpg',
#    'sizes': {'large': {'h': 1338, 'resize': 'fit', 'w': 2048},
#     'medium': {'h': 784, 'resize': 'fit', 'w': 1200},
#     'small': {'h': 444, 'resize': 'fit', 'w': 680},
#     'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#    'type': 'photo',
#    'url': 'https://t.co/lN7hItwPO9'}],
#  'symbols': [],
#  'urls': [],
#  'user_mentions': [{'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'indices': [23, 34],
#    'name': 'MIDAS IIITD',
#    'screen_name': 'midasIIITD'}]}

# %%
tweets_by_MIDAS[10]['extended_entities']
# Out:
# {'media': [{'display_url': 'pic.twitter.com/lN7hItwPO9',
#    'expanded_url': 'https://twitter.com/midasIIITD/status/1105478029147553792/photo/1',
#    'id': 1105477322264772610,
#    'id_str': '1105477322264772610',
#    'indices': [145, 168],
#    'media_url': 'http://pbs.twimg.com/media/D1dxxHzXgAIeNSE.jpg',
#    'media_url_https': 'https://pbs.twimg.com/media/D1dxxHzXgAIeNSE.jpg',
#    'sizes': {'large': {'h': 1338, 'resize': 'fit', 'w': 2048},
#     'medium': {'h': 784, 'resize': 'fit', 'w': 1200},
#     'small': {'h': 444, 'resize': 'fit', 'w': 680},
#     'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#    'type': 'photo',
#    'url': 'https://t.co/lN7hItwPO9'}]}

# %% [markdown]
# ## Second Part - Parse the Json Line file and get the required information in Tabular form

# %%
def parse_tweets(FILE_PATH):
    
    with open(FILE_PATH) as json_file:  
        tweets_by_MIDAS = json.load(json_file)
        
        tweet_list=[]

        for tweet in tweets_by_MIDAS:
            tweet_info=dict()

            tweet_info['Text']=tweet['full_text']
            tweet_info['Date and Time']= tweet['created_at']
            #tweet_info['id_str']=tweet['id_str']

            tweet_info['Number of Likes']=tweet['favorite_count']
            tweet_info['Number of Retweets']=tweet['retweet_count']

            if 'media' in tweet['entities']:
                image_count = 0
                tweet_media = tweet['extended_entities']['media']
                for i in range(len(tweet_media)):
                    if(tweet_media[i]['type'] == 'photo'):
                        image_count += 1
                tweet_info['Number of Images'] = image_count
            else:
                #No media in the tweet, hence None
                tweet_info['Number of Images'] = None
            tweet_list.append(tweet_info)
    return tweet_list

# %%
MIDAS_info = parse_tweets(FILE_PATH)

# %%
MIDAS_info[1]
# Out:
# {'Date and Time': 'Sun Mar 17 14:22:04 +0000 2019',
#  'Number of Images': None,
#  'Number of Likes': 14,
#  'Number of Retweets': 4,
#  'Text': 'Congratulations @midasIIITD team, Rohan, Pradyumn, Ramit, @debanjanbhucs, @MADAIguy and @RatnRajiv for getting their paper titled, "SNAP-BATNET: Cascading Author Profiling and Social Network Graphs for Suicide Ideation Detection on Social Media", accepted at @NAACLHLT SRW.'}

# %%
MIDAS_df = pd.DataFrame(MIDAS_info)

# %%
MIDAS_df
# Out:
#                       Date and Time  Number of Images  Number of Likes  \
# 0    Mon Mar 18 02:27:47 +0000 2019               NaN                6
# 1    Sun Mar 17 14:22:04 +0000 2019               NaN               14
# 2    Sat Mar 16 14:06:56 +0000 2019               NaN                6
# 3    Sat Mar 16 09:20:29 +0000 2019               NaN                1
# 4    Sat Mar 16 09:14:58 +0000 2019               NaN                7
# 5    Sat Mar 16 05:13:14 +0000 2019               NaN                7
# 6    Wed Mar 13 17:09:44 +0000 2019               NaN                0
# 7    Wed Mar 13 04:11:24 +0000 2019               1.0                1
# 8    Wed Mar 13 04:06:04 +0000 2019               NaN                0
# 9    Tue Mar 12 17:43:44 +0000 2019               NaN                0
# 10   Tue Mar 12 14:37:55 +0000 2019               1.0               16
# 11   Mon Mar 11 14:58:30 +0000 2019               NaN                0
# 12   Mon Mar 11 12:02:42 +0000 2019               NaN                4
# 13   Mon Mar 11 11:54:38 +0000 2019               NaN                3
# 14   Mon Mar 11 06:22:12 +0000 2019               NaN                1
# 15   Mon Mar 11 06:17:20 +0000 2019               NaN                0
# 16   Fri Mar 08 13:22:07 +0000 2019               NaN                1
# 17   Fri Mar 08 13:15:34 +0000 2019               NaN                8
# 18   Wed Mar 06 13:44:11 +0000 2019               NaN                3
# 19   Wed Mar 06 11:12:30 +0000 2019               1.0                0
# 20   Sun Mar 03 19:36:04 +0000 2019               NaN                0
# 21   Sun Mar 03 17:09:48 +0000 2019               NaN                1
# 22   Sun Mar 03 15:37:28 +0000 2019               3.0                9
# 23   Sun Mar 03 14:55:31 +0000 2019               NaN                6
# 24   Sun Mar 03 14:26:40 +0000 2019               NaN                0
# 25   Sat Mar 02 17:43:05 +0000 2019               NaN                1
# 11                    0      @saanidhi @ACMMM19 Before Friday, 15th March.
# 12                    0  We are glad to inform that Adobe is launching ...
# 13                    0  We will email tasks to all shortlisted candida...
# 14                    1  @ACMMM19 @ACM_MM2018 @acmmm17 @sigmm @ACM Less...
# 15                   63  RT @kdnuggets: Face Recognition using One-Shot...
# 16                    0  @AvinashSwamina2 @IIITDelhi No. They will be g...
# 17                    4  We are in the process of finalizing the shortl...
# 18                    0  @ylecun @NilayShri @the_dhumketu @debanjanbhuc...
# 19                   22  RT @kdnuggets: Python Data Science for Beginne...
# 20                   35  RT @stanfordnlp: Useful feature of our Python ...
# 21                    0  @NilayShri @NilayShri, Certain thing! The next...
# 22                    1  At @midasIIITD, we not only work hard but also...
# 23                    2  Considering several requests to extend the dea...
# 24                  315  RT @jeremyphoward: 39 studies about human perc...
# 25                    0            Correction:   @midasIIITD at @IIITDelhi
# 26                    1  Thanks much to all aspirants who have applied ...
# 27                    4  RT @kdnuggets: Keras Hyperparameter Tuning in ...
# 28                    1  RT @RatnRajiv: Great meeting with @midasIIITD ...
# 29                    0  Correction: They have published the following ...
# ..                  ...                                                ...
# 264                 265  RT @TensorFlow: TensorFlow 1.10.0 has been rel...
# 265                   1  @midasIIITD is looking for motivated IIITD MTe...
# 266                   1  @IIITDelhi @ponguru @RatnRajiv The results of ...
# 267                   1  RT @IIITDelhi: @midasIIITD has secured rank 1 ...
# 268                  40  RT @kdnuggets: Comparison of Top 6 Python NLP ...
# 269                   1  Check more details of the 20th IEEE Internatio...
# 270                   1  MR2AMC@ISM 2018 will be organized by @RatnRaji...
# 271                   1  Our workshop proposal named, "MR2AMC: Multimod...
# 272                   0  @NUSComputing Congratulations Abdelhak and Pro...
# 273                 103  RT @goodfellow_ian: One of the most anticipate...
# 274                   0     @the_dhumketu Great to have you in @midasIIITD
# 275                   1  Congratulation @soujanyaporia for being appoin...
# 276                   1  @IIITDelhi @the_dhumketu Thanks team @midasIII...
# 277                   4  RT @IIITDelhi: Congratulations @midasIIITD int...
# 278                   4  RT @learning_pt: Profile of the 5 Indian under...
# 279                   0  Have a look at the list of accepted papers in ...
# 280                 264  RT @goodfellow_ian: https://t.co/hYiWI7ntyk Te...
# 281                   2  RT @IIITDelhi: Congratulations Dr. @RatnRajiv ...
# 282                  57  RT @ylecun: Jitendra Malik, who directs FAIR-M...
# 283                 105  RT @kdnuggets: .@Bloomberg launches free cours...
# 284                   7  RT @TechAtBloomberg: Missed #PyLondinium18? Wa...
# 285                   6  RT @IIITDelhi: We are delighted to announce th...
# 286                   2  Get ready for the annual technical fest of @II...
# 287                   2  Congratulations Dr. @RatnRajiv and team @midas...
# 288                   1  Congratulations MIDAS @midasIIITD intern Prakh...
# 289                   1    MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm
# 290                   1  It feels great to be the part of @IIITDelhi. h...
# 291                   1  Thank you, @toonzratn for designing the logo o...
# 292                   1  We are on Facebook too. Like our page to get o...
# 293                   4  MIDAS is a group of researchers at IIIT-Delhi ...
#
# [294 rows x 5 columns]
