# %% [markdown]
# ## Problem statement
# You have to write a python script which can fetch all the tweets(as many as allowed by Twitter
# API) done by [midas@IIITD](https://twitter.com/midasIIITD) twitter handle and dump the responses into JSONlines file.
# The other part of your script should be able to parse these JSONline files to display the
# following for every tweet in a tabular format.
# * The text of the tweet.
# * Date and time of the tweet.
# * The number of favorites/likes.
# * The number of retweets.
# * Number of Images present in Tweet. If no image returns None.

# %% [markdown]
# ### Imports

# %% [markdown]
# First step is to import the required libraries for our task.
# * [Tweepy](http://www.tweepy.org/) is the Python library that can be used to access Twitter API.
# * Other libraries to be imported are:
#     * [json](https://docs.python.org/3.7/library/json.html) - For reading/writing JSON Line files.
#     * [os](https://docs.python.org/3.7/library/os.html) - For OS dependent functionalities such as manipulating path etc.
#     * [pandas](https://pandas.pydata.org/) - A data analysis library. Here, in this notebook, Pandas is used to display information in tabular form.

# %%
import tweepy
from tweepy import OAuthHandler
import json
import os
import pandas as pd

# %%
#Path for storing/retrieving JSON file
FILE_PATH = os.path.join(os.getcwd(), "/Users/Akshay/Desktop/tweets.json")

# %% [markdown]
# ### Authorization

# %% [markdown]
# For accessing data from Twitter API, we'd have to complete an authorization step. For this, it is required to have a [Twitter developer](https://developer.twitter.com/) account. After creating the account, we just have to [create a new app](https://developer.twitter.com/en/apps) and follow the guidlines for filling up some details. Once the app is created successfully, we'll be able to find a page where we can see/generate the consumer key, consumer secret key, access token and access token secret. It is recommended to not make these public, hence `#` is used in the following cell.

# %%
ACCESS_TOKEN = "#"
ACCESS_TOKEN_SECRET = "#"
CONSUMER_KEY = "#"
CONSUMER_SECRET_KEY = "#"

# %% [markdown]
# Tweepy supports accessing Twitter via Basic Authentication and the newer method, OAuth. Twitter has stopped accepting Basic Authentication so we'd have to use OAuth to use the Twitter API. Following cell shows how we can get access to the Twitter API using tweepy with OAuth:

# %%
auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET_KEY)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %% [markdown]
# At this point, Authorization step is completed and now we can head straight to the task.

# %% [markdown]
# ## First Part - Fetch Tweets and Dump them into JSON Line file

# %% [markdown]
#  In the following cell, the function, `fetch_and_dump_tweets(screen_name)` will fetch most recent tweets (only upto 3200) made by `screen_name` and dump them into the JSON file specified earlier by `FILE_PATH`. Specifically, [user_timeline](https://developer.twitter.com/en/docs/tweets/timelines/api-reference/get-statuses-user_timeline.html) API method is used which will return a collection of most recent tweets up to a maximum of 200 per distinct request. Note that, `max_id`, an optional parameter has been added when invoking `user_timeline` after first time. It has been added to return the result with an ID less than (that is, older than) or equal to the specified ID.

# %%
def fetch_and_dump_tweets(screen_name):
    '''
    Parameters-
        screen_name: Twitter handle of the user
    Variables -
        tweets: List (of length upto 200) of tweets by screen_name
        oldest: Index of oldest fetched tweet
        all_tweets_json: List of _json data from all_tweets
    Returns -   
        all_tweets: List of all tweets by screen_name
    '''
    #all_tweets intialized as an empty list
    all_tweets = []
    
    #most recent tweets upto maximum of 200
    tweets = api.user_timeline(screen_name = screen_name,count=200)
    
    #add tweets to all_tweets
    all_tweets.extend(tweets)
    
    #ID of the most recent fetched tweet - 1
    oldest = all_tweets[-1].id - 1
    
    #fetch tweets that are older than most recent 200 tweets until no tweet is left or 3200 limit is reached
    while len(tweets) > 0:
        
        tweets = api.user_timeline(screen_name = screen_name, count=200, max_id=oldest)
        all_tweets.extend(tweets)
        oldest = all_tweets[-1].id - 1

    print(f"Total number of tweets from {screen_name} are {len(all_tweets)}")
    
    #all_tweets_json initialized as an empty list
    all_tweets_json = []
    
    #append _json corresponding to each of the tweet to the all_tweets_json
    for tweet in all_tweets:
        all_tweets_json.append(tweet._json)
        
    #dumping all_tweets_json to the file specified by FILE_PATH
    #sort_keys is set to True for sorting dictionaries by key
    #indent = 4, for pretty printing JSON array elements with indent level of 4
    with open(FILE_PATH, 'w', encoding='utf8') as f:
        json.dump(all_tweets_json, f, sort_keys = True,indent = 4)
    return all_tweets

# %% [markdown]
# Now we'll call this method to fetch tweets by [midas@IIITD](https://twitter.com/midasIIITD).

# %%
tweets_by_MIDAS = fetch_and_dump_tweets("midasIIITD")
# Out:
# Total number of tweets from midasIIITD are 296

# %% [markdown]
# Now, let's load the JSON file into `MIDAS_json`.

# %%
with open(FILE_PATH) as json_file:  
    MIDAS_json = json.load(json_file)

# %% [markdown]
# Let's have a look at how one of these tweet looks like in JSON format.

# %%
MIDAS_json[12]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 12 14:37:55 +0000 2019',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#     'expanded_url': 'https://twitter.com/i/web/status/1105478029147553792',
#     'indices': [110, 133],
#     'url': 'https://t.co/XEkcYO8KmW'}],
#   'user_mentions': [{'id': 1021355762575073281,
#     'id_str': '1021355762575073281',
#     'indices': [23, 34],
#     'name': 'MIDAS IIITD',
#     'screen_name': 'midasIIITD'}]},
#  'favorite_count': 16,
#  'favorited': False,
#  'geo': None,
#  'id': 1105478029147553792,
#  'id_str': '1105478029147553792',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 4,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'text': 'Awesome members of our @midasIIITD team who are working on Humonics projects. Great to have you on our team.… https://t.co/XEkcYO8KmW',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Mon Jul 23 11:26:04 +0000 2018',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'midas.iiitd.edu.in',
#       'expanded_url': 'http://midas.iiitd.edu.in/',
#       'indices': [0, 23],
#       'url': 'https://t.co/Uwg7oSM6mE'}]}},
#   'favourites_count': 118,
#   'follow_request_sent': False,
#   'followers_count': 173,
#   'following': True,
#   'friends_count': 39,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 1021355762575073281,
#   'id_str': '1021355762575073281',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 0,
#   'location': 'New Delhi, India',
#   'name': 'MIDAS IIITD',
#   'notifications': True,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1552394509',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'midasIIITD',
#   'statuses_count': 296,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': 'https://t.co/Uwg7oSM6mE',
#   'utc_offset': None,
#   'verified': False}}

# %% [markdown]
# It looks like `entities` is the one which provides metadata related to a particular tweet. Let's look at going through the `expanded_url` at how this tweet actually looks like on Twitter. ![Snapshot of tweet](https://i.imgur.com/IOoc3g1.png)<center><i>A snapshot of tweet made on March 12.</i></center><br>
# As we can see, this tweet contains an image but there is no detail present about it in `entities`. Hence, we'd have to modify the function `fetch_and_dump_tweets` to get the complete information. After going through this [documentation](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/entities-object.html), it seems we'll have to include `extended_entities` corresponding to each tweet to the JSON file. This can be done by adding parameter `tweet_mode` to the `user_timeline` API method and then setting it to `extended`. Now we are good to go:

# %%
#Redefining the fetch_and_dump_tweets method.

def fetch_and_dump_tweets(screen_name):
    '''
    Parameters-
        screen_name: Twitter handle of the user
    Variables -
        tweets: List (of length upto 200) of tweets by screen_name
        oldest: Index of oldest fetched tweet
        all_tweets_json: List of _json data from all_tweets
    Returns -   
        all_tweets: List of all tweets by screen_name
    '''
    #all_tweets intialized as an empty list
    all_tweets = []
    
    #most recent tweets upto maximum of 200
    #Note that, this time an additional parameter, tweet_mode has been added
    tweets = api.user_timeline(screen_name = screen_name,count=200, tweet_mode='extended')
    
    #add tweets to all_tweets
    all_tweets.extend(tweets)
    
    #ID of the most recent fetched tweet - 1
    oldest = all_tweets[-1].id - 1
    
    #fetch tweets that are older than most recent 200 tweets until no tweet is left or 3200 limit is reached
    while len(tweets) > 0:
        
        #Note that, this time an additional parameter, tweet_mode has been added
        tweets = api.user_timeline(screen_name = screen_name, count=200, max_id=oldest, tweet_mode='extended')
        all_tweets.extend(tweets)
        oldest = all_tweets[-1].id - 1

    print(f"Total number of tweets from {screen_name} are {len(all_tweets)}")
    
    #all_tweets_json initialized as an empty list
    all_tweets_json = []
    
    #append _json corresponding to each of the tweet to the all_tweets_json
    for tweet in all_tweets:
        all_tweets_json.append(tweet._json)
        
    #dumping all_tweets_json to the file specified by FILE_PATH
    #sort_keys is set to True for sorting dictionaries by key
    #indent = 4, for pretty printing JSON array elements with indent level of 4
    with open(FILE_PATH, 'w', encoding='utf8') as f:
        json.dump(all_tweets_json, f, sort_keys = True,indent = 4)
    return all_tweets

# %%
tweets_by_MIDAS = fetch_and_dump_tweets("midasIIITD")
# Out:
# Total number of tweets from midasIIITD are 296

# %%
with open(FILE_PATH) as json_file:  
    MIDAS_json = json.load(json_file)

# %% [markdown]
# Now, let's look at the `entities` of the same tweet.

# %%
MIDAS_json[12]['entities']
# Out:
# {'hashtags': [{'indices': [111, 116], 'text': 'team'},
#   {'indices': [117, 126], 'text': 'research'},
#   {'indices': [127, 130], 'text': 'AI'},
#   {'indices': [131, 134], 'text': 'ML'},
#   {'indices': [135, 144], 'text': 'projects'}],
#  'media': [{'display_url': 'pic.twitter.com/lN7hItwPO9',
#    'expanded_url': 'https://twitter.com/midasIIITD/status/1105478029147553792/photo/1',
#    'id': 1105477322264772610,
#    'id_str': '1105477322264772610',
#    'indices': [145, 168],
#    'media_url': 'http://pbs.twimg.com/media/D1dxxHzXgAIeNSE.jpg',
#    'media_url_https': 'https://pbs.twimg.com/media/D1dxxHzXgAIeNSE.jpg',
#    'sizes': {'large': {'h': 1338, 'resize': 'fit', 'w': 2048},
#     'medium': {'h': 784, 'resize': 'fit', 'w': 1200},
#     'small': {'h': 444, 'resize': 'fit', 'w': 680},
#     'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#    'type': 'photo',
#    'url': 'https://t.co/lN7hItwPO9'}],
#  'symbols': [],
#  'urls': [],
#  'user_mentions': [{'id': 1021355762575073281,
#    'id_str': '1021355762575073281',
#    'indices': [23, 34],
#    'name': 'MIDAS IIITD',
#    'screen_name': 'midasIIITD'}]}

# %%
MIDAS_json[12]['extended_entities']
# Out:
# {'media': [{'display_url': 'pic.twitter.com/lN7hItwPO9',
#    'expanded_url': 'https://twitter.com/midasIIITD/status/1105478029147553792/photo/1',
#    'id': 1105477322264772610,
#    'id_str': '1105477322264772610',
#    'indices': [145, 168],
#    'media_url': 'http://pbs.twimg.com/media/D1dxxHzXgAIeNSE.jpg',
#    'media_url_https': 'https://pbs.twimg.com/media/D1dxxHzXgAIeNSE.jpg',
#    'sizes': {'large': {'h': 1338, 'resize': 'fit', 'w': 2048},
#     'medium': {'h': 784, 'resize': 'fit', 'w': 1200},
#     'small': {'h': 444, 'resize': 'fit', 'w': 680},
#     'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#    'type': 'photo',
#    'url': 'https://t.co/lN7hItwPO9'}]}

# %% [markdown]
# Success! Now we have the media related information and this completes the first part of our task.

# %% [markdown]
# ## Second Part - Parse the JSON Line file and get the required information in Tabular form

# %% [markdown]
# The second part of the task is to parse the JSON file we created in first part and get the required data in the tabular form. This part will contain a function: `parse_tweets(FILE_PATH)` to parse the JSONline file specified by `FILE_PATH` and return the information as a python list: `tweet_list`. `tweet_list` can then later be displayed in a tabular format as demonstrated in the subsequence cells.

# %%
def parse_tweets(FILE_PATH):
    '''
    Parameters-
        FILE_PATH: Path to the JSON file (tweets.json)
    Variables -
        tweets_by_MIDAS: List to load in the data from tweets.json
        tweet_info: Dictionary that will hold the required information for a tweet
        image_count: Counter for number of images in a tweet
        tweet_media: List that will hold all the media related information of a tweet
    Returns -   
        tweet_list: List of tweet_info
    '''
    #load tweets.json to tweets_by_MIDAS
    with open(FILE_PATH) as json_file:
        tweets_by_MIDAS = json.load(json_file)
        
        #tweet_list initialized as an empty list
        tweet_list=[]

        #Go through the json data of each tweet one by one
        for tweet in tweets_by_MIDAS:
            
            #an empty dictionary for a tweet
            tweet_info=dict()
            
            #get the text of tweet
            tweet_info['Text']=tweet['full_text']
            
            #get the date and time of the tweet
            tweet_info['Date and Time']= tweet['created_at']
            
            #get the number of likes and retweets for the tweet
            tweet_info['Number of Likes']=tweet['favorite_count']
            tweet_info['Number of Retweets']=tweet['retweet_count']

            #check if tweet contains any kind of media
            if 'media' in tweet['entities']:
                
                image_count = 0
                
                #get the media information about tweet
                tweet_media = tweet['extended_entities']['media']
                
                #go through all the media and check if it's photo/image
                #if yes, then increment the image_count
                for i in range(len(tweet_media)):
                    if(tweet_media[i]['type'] == 'photo'):
                        image_count += 1
                tweet_info['Number of Images'] = image_count
                
            #No media, hence set number of images to None    
            else:
                tweet_info['Number of Images'] = None
                
            #append the tweet_info to tweet_list    
            tweet_list.append(tweet_info)
    return tweet_list

# %%
MIDAS_info = parse_tweets(FILE_PATH)

# %%
MIDAS_info[1]
# Out:
# {'Date and Time': 'Wed Mar 20 02:40:07 +0000 2019',
#  'Number of Images': None,
#  'Number of Likes': 0,
#  'Number of Retweets': 3,
#  'Text': 'RT @IEEEBigMM19: BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals  \n\nhttps://t.co/I4vqf8FE6K …  \nWhen: Sep 11, 2019 - Sep 13, 201…'}

# %% [markdown]
# At this point, we are almost done and just have to transform the `midas_info` into a tabular form. It can be easily done by using [pandas.DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html) as shown in the below cell.

# %%
pd.options.display.max_rows = 3200 #To show all the rows
MIDAS_df = pd.DataFrame(MIDAS_info)
MIDAS_df = MIDAS_df[['Text', 'Date and Time', 'Number of Likes', 'Number of Retweets', 'Number of Images']] #Reorder columns
MIDAS_df.where(MIDAS_df.notnull(), None) #Replace NaN with None
# Out:
#                                                   Text  \
# 0    @IEEEBigMM19 is also available on Facebook now...
# 1    RT @IEEEBigMM19: BigMM 2019 : IEEE BigMM 2019 ...
# 2    BigMM 2019 : IEEE BigMM 2019 – Call for Worksh...
# 3    Congratulations @midasIIITD team, Rohan, Prady...
# 4    We have emailed the task details to all shortl...
# 5    IEEE BigMM 2019 - Call for Workshop Proposals....
# 6    Congratulations! Arijit, Ramit, @debanjanbhucs...
# 7    We will be releasing a very interesting task t...
# 8    RT @hcdiiitd: Last day to register for #Portfo...
# 9    @ACMMM19 @sigmm @TheOfficialACM @acmmmsys @ACM...
# 10   RT @ACMMM19: The paper deadline is approaching...
# 11   RT @kaggle: Bookmark this amazing library of i...
# 12   Awesome members of our @midasIIITD team who ar...
# 13       @saanidhi @ACMMM19 Before Friday, 15th March.
# 14   We are glad to inform that Adobe is launching ...
# 15   We will email tasks to all shortlisted candida...
# 16   @ACMMM19 @ACM_MM2018 @acmmm17 @sigmm @ACM Less...
# 17   RT @kdnuggets: Face Recognition using One-Shot...
# 18   @AvinashSwamina2 @IIITDelhi No. They will be g...
# 19   We are in the process of finalizing the shortl...
# 20   @ylecun @NilayShri @the_dhumketu @debanjanbhuc...
# 21   RT @kdnuggets: Python Data Science for Beginne...
# 22   RT @stanfordnlp: Useful feature of our Python ...
# 23   @NilayShri @NilayShri, Certain thing! The next...
# 24   At @midasIIITD, we not only work hard but also...
# 25   Considering several requests to extend the dea...
# 26   RT @jeremyphoward: 39 studies about human perc...
# 27             Correction:   @midasIIITD at @IIITDelhi
# 28   Thanks much to all aspirants who have applied ...
# 29   RT @kdnuggets: Keras Hyperparameter Tuning in ...
# 30   RT @RatnRajiv: Great meeting with @midasIIITD ...
# 31   Correction: They have published the following ...
# 32   We will process all applications received by M...
# 33   RT @ecsquendor: Jit Ghosh discusses the "GloVe...
# 34   RT @goodfellow_ian: This CVPR workshop is look...
# 35   RT @IIITDelhi: PhD Admission 2019 are open now...
# 36   RT @kdnuggets: #AI for Social Good study - how...
# 37   @IIITDelhi has initiated PhD Admission 2019 pr...
# 38   RT @radamihalcea: We tend to focus mainly on c...
# 39   @RealAAAI @RatnRajiv Thanks, @RealAAAI for rec...
# 40   Deepak Gupta, has joined @Google today. \nEarl...
# 41   RT @ACMMM19: We are pleased to announce the mu...
# 42   In addition to projects related to NLP and Mul...
# 43   RT @technology: What could the manufacturing i...
# 44   RT @MSFTResearch: Dr. Layla El Asri wants you ...
# 45   To apply for @midasIIITD internship at @IIITDe...
# 46   RT @CornellDyson: Digital ag is Cornell’s newe...
# 47   RT @odsc: Introduction to StanfordNLP: a state...
# 48   Looking forward to your participation in Multi...
# 49   Consider attending National Workshop on Intell...
# 50   Submissions are invited for a special issue of...
# 51          RT @debanjanbhucs: https://t.co/qNFzJ7ZHki
# 52   RT @MSFTResearch: Congratulations to Manik Var...
# 53   Congratulations! Anupam Samanta on joining @Go...
# 54   RT @kdnuggets: Using BERT for state-of-the-art...
# 55   RT @ACMMM19: Attention authors of ACM MultiMed...
# 56   RT @kdnuggets: 9 Must-have skills you need to ...
# 57   @ACMMM19 @ACM Just one week is left for worksh...
# 58   @NilayShri @the_dhumketu Thanks, @NilayShri fo...
# 59   RT @NilayShri: @midasIIITD @the_dhumketu this ...
# 60   RT @kdnuggets: Machine Learning in Python by @...
# 61   RT @Cambridge_Uni: .@DeepMindAI and @Cambridge...
# 62   RT @GoogleAI: Google AI  and @DeepMindAI resea...
# 63   Edit: In the updated leaderboard we are now ra...
# 64   Congratulations! @isarth23. \nIt is our pleasu...
# 65   In addition to OffensEval task, @midasIIITD ha...
# 66   Thanks, Karan Uppal and @RatnRajiv for all you...
# 67   @midasIIITD performance in OffensEval 2019 (Se...
# 68   RT @ProfAnirban: One of the biggest obstacles ...
# 69   RT @IIITDelhi: Students of @midasIIITD lab won...
# 70   @RealAAAI 2019 summary for @midasIIITD.\n1 pap...
# 71   @the_dhumketu @RealAAAI Congrats! Raghav, Kshi...
# 72   Our paper titled, "Mind Your Language: Abuse a...
# 73   RT @PeterMartigny: Very interesting talk by @C...
# 74   RT @NilayShri: @midasIIITD @RatnRajiv\n@the_dh...
# 75   CFP for @ACMMM19 has been posted on WikiCFP. K...
# 76   @midasIIITD Lab is pleased to share our novel ...
# 77   RT @RatnRajiv: If you are attending @RealAAAI ...
# 78   RT @RatnRajiv: Great to be part of this year's...
# 79   RT @MIT: Want to squelch fake news? Let the re...
# 80   If you are attending @RealAAAI 2019 at Honolul...
# 81   If you are attending @RealAAAI 2019 then visit...
# 82   If you are attending @RealAAAI 2019 then visit...
# 83   If you are attending @RealAAAI 2019 then visit...
# 84   @TechAtBloomberg @debanjanbhucs It is a great ...
# 85   RT @TechAtBloomberg: Learn more about the coll...
# 86   RT @debanjanbhucs: We as researchers working a...
# 87   RT @kdnuggets: 7 Steps to Mastering Basic Mach...
# 88   @TechAtBloomberg @debanjanbhucs @IIITDelhi @Ra...
# 89   RT @TechAtBloomberg: #Textanalytics researcher...
# 90   RT @kdnuggets: Top 16 #OpenSource #DeepLearnin...
# 91   RT @Princeton: Using data from more than 6,000...
# 92   RT @CornellBirds: In 1929 Cornell Lab founder ...
# 93   RT @seb_ruder: Natural Questions: A new QA dat...
# 94   RT @kdnuggets: 10 More #Free Must-Read #Books ...
# 95   RT @kdnuggets: How to build an API for a machi...
# 96   @ACMMM19 @ACM @abhinavdhall consider submittin...
# 97   RT @ACMMM19: Jump start your @ACM #Multimedia ...
# 98   @NUSComputing Congratulations! Yaman @the_dhum...
# 99        ⚡️ “Achievements”\n\nhttps://t.co/LvZt1GTY4C
# 100  RT @NUSComputing: A/P Roger Zimmermann and his...
# 101  Welcome one member to our @midasIIITD family, ...
# 102  Dr @RatnRajiv Shah delivered a research talk i...
# 103  RT @Scott__Hubbard: Don't miss this new articl...
# 104  RT @kaggle: Stuck inside with stir-crazy kids?...
# 105  @Princeton @nyuniversity @nytimes Team @midasI...
# 106  RT @Harvard: Researchers find connections betw...
# 107  RT @Stanford: Researchers across Stanford are ...
# 108  Meet our members of @midasIIITD .\n\nhttps://t...
# 109  RT @kdnuggets: How to Monitor Machine Learning...
# 110  Congratulations! @Leomi7 @ashualloy @RatnRajiv...
# 111  RT @jasonbaumgartne: #Pushshift is happy to an...
# 112  Proceedings of FIRE 2018 is online now at http...
# 113  RT @hseas: Only 20 percent of pediatric cancer...
# 114  RT @Cornell: Can virtual reality transform med...
# 115  RT @kdnuggets: Explainable Artificial Intellig...
# 116              @abhinavdhall @RatnRajiv Emailed you.
# 117  RT @kdnuggets: A comprehensive list of #Machin...
# 118  Call for Book Chapter- Springer- Deep learning...
# 119  RT @Stanford: The average woman is exposed to ...
# 120  @harvardmed @Harvard Another interesting direc...
# 121  RT @harvardmed: A first-of-its-kind strategy a...
# 122  RT @RatnRajiv: Fortunate to have appreciation ...
# 123  RT @Harvard: The study provides potential futu...
# 124  RT @UniofOxford: In the final episode of serie...
# 125  @ACMMM19: Call for Workshop Proposals \n\nDead...
# 126  @ACMMM19: Call for Grand Challenge Proposals\n...
# 127  Since 1993, ACM Multimedia has been bringing t...
# 128  @ACMMM19 is structured around four themes (alp...
# 129  ACM Multimedia 2019: First Call for Papers/Cal...
# 130  RT @ACMMM19: Happy new year! 2019 started with...
# 131  You may follow @midasIIITD updates through fol...
# 132  Today, @midasIIITD completed one year at @IIIT...
# 133  RT @debanjanbhucs: Happy anniversary to @midas...
# 134  Two Research Assistant (RA) positions are stil...
# 135  Positions for two Research Assistants (RA) are...
# 136  RT @TCoolsIT: I wrote a blogpost on CoreNLP hi...
# 137  @RatnRajiv delivered a research talk at the Ce...
# 138  @midasIIITD look forward to work together. htt...
# 139  @the_dhumketu @punnibhai @Hitkul_, FYI. https:...
# 140  RT @iiit_hyderabad: KCIS Distinguished Lecture...
# 141  RT @StanfordAILab: Our latest blog post is out...
# 142  RT @medialab: In two new papers, @PratikShahPh...
# 143  RT @RatnRajiv: Wonderful get together with our...
# 144  @ACMMM19 is the premier international conferen...
# 145  Feel free to contact us if you have any query ...
# 146  @NilayShri @RatnRajiv @ACMMM19 Looking forward...
# 147  @midasIIITD head, Dr. @RatnRajiv appointed as ...
# 148  @ACMMM19 @the_dhumketu fill the volunteer form...
# 149  RT @ACMMM19: New in 2019! Volunteer to serve a...
# 150  RT @IIITDelhi: Congratulations! authors Yaman ...
# 151  Best wishes to @midasIIITD students @_himanshu...
# 152  RT @MIT: Computer model could improve human-ma...
# 153  RT @kdnuggets: Great @Wired interview with Geo...
# 154  RT @harvardmed: A defective metabolic pathway ...
# 155  RT @stanfordnlp: Thread on (neural) reasoning....
# 156  Congratulations! Yaman @the_dhumketu, Rohit, S...
# 157  Yaman @the_dhumketu presented our idea of reco...
# 158  Several Research Assistant and Intern position...
# 159  RT @kdnuggets: Variational Autoencoders Explai...
# 160  Positions for research assistants and interns ...
# 161  Congratulations @Leomi7 Meghna, @punnibhai Pun...
# 162  Application for Ph.D. admission at @IIITDelhi ...
# 163  RT @NirantK: 1/n The Wonderful World of Fine T...
# 164  RT @the_dhumketu: My 2 full papers and 2 stude...
# 165  @the_dhumketu @sundarpichai @GoogleAI @Googleo...
# 166  Two @midasIIITD interns, @Leomi7 and Sahil Cho...
# 167  Need Help Getting Started with Applied Machine...
# 168  Two student papers got accepted at AAAI despit...
# 169  Another #ACMMM18 paper titled, "Learning and F...
# 170  Our paper on "Harnessing AI for Speech Reconst...
# 171  RT @debanjanbhucs: One of our papers on "Detec...
# 172  Training Neural Nets on Larger Batches: Practi...
# 173     @smnh_azadi @goodfellow_ian FYI, @the_dhumketu
# 174  RT @smnh_azadi: Apply this simple rejection sa...
# 175  @UniofOxford @turinginst Check @Leomi7 @punnibhai
# 176  RT @soujanyaporia: We are making available a l...
# 177  Thank you, Dr. Debanjan Mahata @debanjanbhucs ...
# 178  RT @mr2amc: Dear Colleagues, \n\n3 more days t...
# 179  RT @AKASH_2907: My internship experience @mida...
# 180  @AKASH_2907 @AKASH_2907, it was great having y...
# 181  The demo of our MyLipper system which got acce...
# 182  Congratulations Yaman @the_dhumketu, Rohit, Sa...
# 183  RT @mr2amc: Dear Colleagues,\n@mr2amc Deadline...
# 184  Congratulations Puneet Mathur @punnibhai , Meg...
# 185  MTech and Ph.D. students of @IIITDelhi, if you...
# 186  Thank you, @nvidia for your support. https://t...
# 187  RT @mr2amc: MR2AMC'18: Multimodal Representati...
# 188  RT @OriolVinyalsML: Best GAN samples ever yet?...
# 189  RT @radamihalcea: I compiled a list of top ten...
# 190  RT @RatnRajiv: Too many Turing awards, Field m...
# 191  RT @RatnRajiv: Thank you, @HLForum for organiz...
# 192  Congrats @midasIIITD student @Simcyy for getti...
# 193  RT @mr2amc: MR2AMC'18: Multimodal Representati...
# 194  RT @mr2amc: Please submit your research papers...
# 195  RT @debanjanbhucs: Summarizing some recent dev...
# 196  RT @debanjanbhucs: Excellent post for those wo...
# 197  @sharmadrishti @IIITDelhi @emnlp2018 Thank you...
# 198  RT @IIITDelhi: Congratulations team @midasIIIT...
# 199  RT @kdnuggets: Auto-Keras, or How You can Crea...
# 200  RT @jain49: Big Change: Diabetes patients are ...
# 201  RT @NipsConference: #NIPS2018 The main confere...
# 202  Paper titled, "Exploring and Learning Suicidal...
# 203  The fourth paper (and 3rd of @punnibhai) got a...
# 204  RT @NAACLHLT: Calls for papers for #naacl2019 ...
# 205  RT @kdnuggets: Text Classification &amp; Embed...
# 206  RT @mr2amc: @mr2amc challenge on "Multimodal S...
# 207  RT @TheWebConf: Submitting to The Web Conferen...
# 208  RT @kdnuggets: First Steps of Learning Deep Le...
# 209  @debanjanbhucs @debanjanbhucs, thanks for shar...
# 210  RT @DaveRubal: GREAT 9-page reference in basic...
# 211  RT @ylecun: Nice blog post about FAIR's work o...
# 212  If you are holding Junior Research Fellowship ...
# 213  RT @goodfellow_ian: https://t.co/46MisEZT5n De...
# 214  @BloodDonorsIn Not everyone is aware of your h...
# 215  @BloodDonorsIn you may call us at 01126907495 ...
# 216  RT @ylecun: Many European country should drama...
# 217  RT @ponguru: Need Hindi-English Code-Mixed #PO...
# 218  RT @kdnuggets: NVIDIA Blog: Supervised Vs. Uns...
# 219  RT @DheerajSanghi: Delhi government nods const...
# 220  @medialab @TechXplore_com an interesting probl...
# 221  RT @DheerajSanghi: Google data collection rese...
# 222  RT @assert_pub: "Ubiquitous Event Mining to En...
# 223  Congratulations @midasIIITD PI, @RatnRajiv, on...
# 224  RT @jain49: Great to hear this.  #FoodComputin...
# 225  @ponguru @IIITDelhi @AhujaSheetu @DheerajSangh...
# 226  RT @kdnuggets: Understanding Deep Convolutiona...
# 227  RT @hardmaru: Everybody Dance Now!\nExciting n...
# 228  RT @YejinChoinka: We have a hot new dataset fo...
# 229  RT @radamihalcea: We are releasing a brand new...
# 230  "Did you offend me? Classification of Offensiv...
# 231  Congratulations @midasIIITD interns, @punnibha...
# 232                            https://t.co/GOyrocgXf4
# 233  TCS Foundation inaugurated Centre for Design a...
# 234  @RatnRajiv Another paper will help companies o...
# 235  Congratulations all @midasIIITD interns for yo...
# 236  @Thom_Wolf @stanfordnlp @sivareddyg @hhexiy @y...
# 237         @danqi_chen @stanfordnlp FYI @the_dhumketu
# 238  RT @kdnuggets: Awesome #DeepLearning: Most Cit...
# 239  RT @stanfordnlp: People usually get informatio...
# 240  Team @midasIIITD looking forward to with CDNM....
# 241  RT @VeredShwartz: After 3 years of blogging ab...
# 242  RT @msisodia: With immense ambition &amp; hope...
# 243  RT @goodfellow_ian: Video-to-video translation...
# 244  RT @kaggle: RT @afshinea 🔥Set of illustrated M...
# 245  RT @jain49: Beginning to understand what we ea...
# 246  Our paper titled, "IceBreaker: Solving Cold St...
# 247  RT @mr2amc: Call for papers: MR2AMC 2018, Taic...
# 248  Our paper titled, "Neural Machine Translation ...
# 249  RT @mr2amc: Team @midasIIITD, please spread CF...
# 250  RT @mr2amc: Our paper submission system is rea...
# 251  RT @NurtureAI: How do you choose the hyperpara...
# 252  RT @kdnuggets: Diving Deep into Deepfakes http...
# 253  Congratulations @midasIIITD @IIITDelhi interns...
# 254  RT @jain49: This is magic. In fact, more than ...
# 255  RT @kdnuggets: The Best Metric to Measure Accu...
# 256  RT @kdnuggets: KDnuggets 18:n31: Top 10 roles ...
# 257  RT @ponguru: Looking for ideas / projects in #...
# 258  RT @coling2018: #COLING2018 proceedings are no...
# 259  Very interesting! We at @midasIIITD, also doin...
# 260  RT @kdnuggets: GitHub Python Data Science Spot...
# 261  RT @mr2amc: @mr2amc will be organized by Prof ...
# 262  RT @mr2amc: Our workshop proposal on Multimoda...
# 263  NLP's ImageNet moment has arrived » https://t....
# 264    @soujanyaporia @nlp Congrats Dr. @soujanyaporia
# 265  RT @kdnuggets: Ultimate Guide to Getting Start...
# 266  RT @TensorFlow: TensorFlow 1.10.0 has been rel...
# 267  @midasIIITD is looking for motivated IIITD MTe...
# 268  @IIITDelhi @ponguru @RatnRajiv The results of ...
# 269  RT @IIITDelhi: @midasIIITD has secured rank 1 ...
# 270  RT @kdnuggets: Comparison of Top 6 Python NLP ...
# 271  Check more details of the 20th IEEE Internatio...
# 272  MR2AMC@ISM 2018 will be organized by @RatnRaji...
# 273  Our workshop proposal named, "MR2AMC: Multimod...
# 274  @NUSComputing Congratulations Abdelhak and Pro...
# 275  RT @goodfellow_ian: One of the most anticipate...
# 276     @the_dhumketu Great to have you in @midasIIITD
# 277  Congratulation @soujanyaporia for being appoin...
# 278  @IIITDelhi @the_dhumketu Thanks team @midasIII...
# 279  RT @IIITDelhi: Congratulations @midasIIITD int...
# 280  RT @learning_pt: Profile of the 5 Indian under...
# 281  Have a look at the list of accepted papers in ...
# 282  RT @goodfellow_ian: https://t.co/hYiWI7ntyk Te...
# 283  RT @IIITDelhi: Congratulations Dr. @RatnRajiv ...
# 284  RT @ylecun: Jitendra Malik, who directs FAIR-M...
# 285  RT @kdnuggets: .@Bloomberg launches free cours...
# 286  RT @TechAtBloomberg: Missed #PyLondinium18? Wa...
# 287  RT @IIITDelhi: We are delighted to announce th...
# 288  Get ready for the annual technical fest of @II...
# 289  Congratulations Dr. @RatnRajiv and team @midas...
# 290  Congratulations MIDAS @midasIIITD intern Prakh...
# 291    MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm
# 292  It feels great to be the part of @IIITDelhi. h...
# 293  Thank you, @toonzratn for designing the logo o...
# 294  We are on Facebook too. Like our page to get o...
# 295  MIDAS is a group of researchers at IIIT-Delhi ...
#
#                       Date and Time  Number of Likes  Number of Retweets  \
# 0    Wed Mar 20 08:19:24 +0000 2019                1                   1
# 1    Wed Mar 20 02:40:07 +0000 2019                0                   3
# 2    Mon Mar 18 02:27:47 +0000 2019                6                   3
# 3    Sun Mar 17 14:22:04 +0000 2019               14                   4
# 4    Sat Mar 16 14:06:56 +0000 2019                6                   0
# 5    Sat Mar 16 09:20:29 +0000 2019                1                   1
# 6    Sat Mar 16 09:14:58 +0000 2019                7                   2
# 7    Sat Mar 16 05:13:14 +0000 2019                7                   2
# 8    Wed Mar 13 17:09:44 +0000 2019                0                   2
# 9    Wed Mar 13 04:11:24 +0000 2019                1                   0
# 10   Wed Mar 13 04:06:04 +0000 2019                0                  13
# 11   Tue Mar 12 17:43:44 +0000 2019                0                  69
# 12   Tue Mar 12 14:37:55 +0000 2019               16                   4
# 13   Mon Mar 11 14:58:30 +0000 2019                0                   0
# 14   Mon Mar 11 12:02:42 +0000 2019                4                   0
# 15   Mon Mar 11 11:54:38 +0000 2019                3                   0
# 16   Mon Mar 11 06:22:12 +0000 2019                1                   1
# 17   Mon Mar 11 06:17:20 +0000 2019                0                  64
# 18   Fri Mar 08 13:22:07 +0000 2019                1                   0
# 19   Fri Mar 08 13:15:34 +0000 2019                8                   4
# 20   Wed Mar 06 13:44:11 +0000 2019                3                   0
# 21   Wed Mar 06 11:12:30 +0000 2019                0                  22
# 22   Sun Mar 03 19:36:04 +0000 2019                0                  35
# 23   Sun Mar 03 17:09:48 +0000 2019                1                   0
# 24   Sun Mar 03 15:37:28 +0000 2019                9                   1
# 25   Sun Mar 03 14:55:31 +0000 2019                6                   2
# 26   Sun Mar 03 14:26:40 +0000 2019                0                 314
# 27   Sat Mar 02 17:43:05 +0000 2019                1                   0
# 28   Sat Mar 02 09:59:03 +0000 2019                7                   1
# 29   Thu Feb 28 14:21:21 +0000 2019                0                   4
# 30   Tue Feb 26 18:30:52 +0000 2019                0                   1
# 31   Tue Feb 26 03:40:22 +0000 2019                0                   0
# 32   Mon Feb 25 16:10:46 +0000 2019                2                   1
# 33   Sun Feb 24 03:39:40 +0000 2019                0                   8
# 34   Sat Feb 23 15:41:27 +0000 2019                0                  90
# 35   Fri Feb 22 11:54:49 +0000 2019                0                   8
# 36   Thu Feb 21 16:27:54 +0000 2019                0                  14
# 37   Thu Feb 21 06:39:27 +0000 2019                2                   1
# 38   Thu Feb 21 04:48:24 +0000 2019                0                  13
# 39   Wed Feb 20 07:09:19 +0000 2019                4                   2
# 40   Wed Feb 20 05:38:29 +0000 2019                4                   2
# 41   Tue Feb 19 17:16:24 +0000 2019                0                  15
# 42   Tue Feb 19 04:29:33 +0000 2019                3                   2
# 43   Tue Feb 19 04:19:05 +0000 2019                0                 292
# 44   Tue Feb 19 04:18:53 +0000 2019                0                  22
# 45   Mon Feb 18 17:29:44 +0000 2019               11                   9
# 46   Mon Feb 18 05:37:59 +0000 2019                0                   6
# 47   Sun Feb 17 17:22:06 +0000 2019                0                  51
# 48   Sun Feb 17 09:02:28 +0000 2019                3                   1
# 49   Sun Feb 17 08:49:36 +0000 2019                1                   0
# 50   Sun Feb 17 06:39:30 +0000 2019                1                   1
# 51   Sat Feb 16 16:57:51 +0000 2019                0                   1
# 52   Fri Feb 15 08:22:23 +0000 2019                0                  13
# 53   Thu Feb 14 15:56:14 +0000 2019               14                   4
# 54   Wed Feb 13 18:56:13 +0000 2019                0                   5
# 55   Wed Feb 13 15:54:52 +0000 2019                0                  11
# 56   Wed Feb 13 05:56:05 +0000 2019                0                  11
# 57   Thu Feb 07 19:21:52 +0000 2019                1                   1
# 58   Thu Feb 07 15:49:59 +0000 2019                0                   0
# 59   Thu Feb 07 15:49:08 +0000 2019                0                   1
# 60   Thu Feb 07 06:23:10 +0000 2019                0                  53
# 61   Wed Feb 06 11:26:25 +0000 2019                0                  35
# 62   Tue Feb 05 18:32:54 +0000 2019                0                 211
# 63   Tue Feb 05 17:45:09 +0000 2019                0                   0
# 64   Tue Feb 05 17:44:27 +0000 2019                4                   0
# 65   Tue Feb 05 12:09:44 +0000 2019                5                   1
# 66   Tue Feb 05 11:55:41 +0000 2019                1                   1
# 67   Tue Feb 05 11:06:31 +0000 2019                4                   3
# 68   Mon Feb 04 12:16:16 +0000 2019                0                  39
# 69   Mon Feb 04 10:58:53 +0000 2019                0                   4
# 70   Sat Feb 02 05:05:16 +0000 2019                7                   3
# 71   Fri Feb 01 07:46:57 +0000 2019                3                   1
# 72   Fri Feb 01 07:30:53 +0000 2019               24                   3
# 73   Fri Feb 01 03:15:27 +0000 2019                0                   8
# 74   Fri Feb 01 03:13:23 +0000 2019                0                   2
# 75   Thu Jan 31 06:57:04 +0000 2019                1                   1
# 76   Thu Jan 31 05:50:19 +0000 2019                4                   2
# 77   Thu Jan 31 05:32:43 +0000 2019                0                   2
# 78   Wed Jan 30 19:46:11 +0000 2019                0                   2
# 79   Wed Jan 30 17:18:40 +0000 2019                0                  11
# 80   Wed Jan 30 05:00:29 +0000 2019                3                   1
# 81   Tue Jan 29 19:42:10 +0000 2019                5                   2
# 82   Tue Jan 29 19:39:29 +0000 2019                3                   1
# 83   Tue Jan 29 19:31:35 +0000 2019                2                   1
# 84   Tue Jan 29 18:05:01 +0000 2019                5                   2
# 85   Tue Jan 29 18:03:31 +0000 2019                0                   5
# 86   Tue Jan 29 17:52:23 +0000 2019                0                   2
# 87   Tue Jan 29 14:52:24 +0000 2019                0                  33
# 88   Tue Jan 29 05:17:27 +0000 2019                3                   1
# 89   Tue Jan 29 04:40:47 +0000 2019                0                   5
# 90   Mon Jan 28 12:11:29 +0000 2019                0                   8
# 91   Mon Jan 28 12:11:13 +0000 2019                0                  20
# 92   Mon Jan 28 12:10:37 +0000 2019                0                  68
# 93   Fri Jan 25 08:56:54 +0000 2019                0                 141
# 94   Thu Jan 24 15:43:25 +0000 2019                0                  24
# 95   Thu Jan 24 15:42:59 +0000 2019                0                  26
# 96   Wed Jan 23 10:24:14 +0000 2019                0                   0
# 97   Wed Jan 23 10:23:34 +0000 2019                0                  10
# 98   Tue Jan 22 14:04:40 +0000 2019                1                   1
# 99   Tue Jan 22 14:02:51 +0000 2019                3                   1
# 100  Tue Jan 22 13:58:08 +0000 2019                0                   2
# 101  Mon Jan 21 16:29:31 +0000 2019                9                   1
# 102  Mon Jan 21 15:19:33 +0000 2019                6                   2
# 103  Mon Jan 21 09:33:03 +0000 2019                0                   9
# 104  Mon Jan 21 09:32:03 +0000 2019                0                  37
# 105  Mon Jan 21 06:54:14 +0000 2019                0                   0
# 106  Sun Jan 20 05:49:19 +0000 2019                0                  77
# 107  Sat Jan 19 18:15:35 +0000 2019                0                   8
# 108  Sat Jan 19 09:59:16 +0000 2019                7                   2
# 109  Sat Jan 19 03:27:33 +0000 2019                0                   9
# 110  Fri Jan 18 10:25:41 +0000 2019                6                   0
# 111  Fri Jan 18 10:17:02 +0000 2019                0                  20
# 112  Fri Jan 18 10:16:26 +0000 2019               10                   2
# 113  Thu Jan 17 04:04:16 +0000 2019                0                  27
# 114  Thu Jan 17 04:03:55 +0000 2019                0                  11
# 115  Sun Jan 13 16:45:48 +0000 2019                0                  20
# 116  Sun Jan 13 16:40:46 +0000 2019                0                   0
# 117  Sun Jan 13 16:03:25 +0000 2019                0                  41
# 118  Sun Jan 13 07:19:19 +0000 2019                6                   1
# 119  Sat Jan 12 14:37:07 +0000 2019                0                  48
# 120  Thu Jan 10 08:51:20 +0000 2019                1                   0
# 121  Thu Jan 10 08:50:35 +0000 2019                0                  27
# 122  Thu Jan 10 08:48:17 +0000 2019                0                   3
# 123  Wed Jan 09 02:05:06 +0000 2019                0                   9
# 124  Mon Jan 07 09:05:12 +0000 2019                0                  16
# 125  Sun Jan 06 12:54:06 +0000 2019                1                   0
# 126  Sun Jan 06 04:29:25 +0000 2019                1                   0
# 127  Sun Jan 06 04:09:54 +0000 2019                5                   1
# 128  Sun Jan 06 04:07:29 +0000 2019                1                   0
# 129  Sun Jan 06 04:05:38 +0000 2019                4                   2
# 130  Thu Jan 03 06:14:05 +0000 2019                0                   2
# 131  Tue Jan 01 17:21:49 +0000 2019                4                   2
# 132  Tue Jan 01 17:17:56 +0000 2019               14                   5
# 133  Tue Jan 01 16:14:24 +0000 2019                0                   4
# 134  Thu Dec 27 10:28:31 +0000 2018                2                   1
# 135  Thu Dec 27 09:59:06 +0000 2018                5                   3
# 136  Thu Dec 27 02:33:58 +0000 2018                0                  12
# 137  Wed Dec 26 09:41:04 +0000 2018               14                   2
# 138  Tue Dec 25 04:15:15 +0000 2018                1                   0
# 139  Tue Dec 25 03:00:21 +0000 2018                2                   1
# 140  Mon Dec 24 07:39:21 +0000 2018                0                  12
# 141  Fri Dec 21 03:50:39 +0000 2018                0                  32
# 142  Thu Dec 20 18:05:35 +0000 2018                0                   8
# 143  Thu Dec 20 06:14:52 +0000 2018                0                   3
# 144  Wed Dec 19 02:16:31 +0000 2018                2                   3
# 145  Tue Dec 18 14:42:27 +0000 2018                3                   2
# 146  Tue Dec 18 14:27:12 +0000 2018                3                   0
# 147  Tue Dec 18 14:15:32 +0000 2018               12                   5
# 148  Tue Dec 18 12:34:10 +0000 2018                1                   0
# 149  Tue Dec 18 12:33:42 +0000 2018                0                   7
# 150  Tue Dec 18 04:38:35 +0000 2018                0                   3
# 151  Mon Dec 17 16:57:00 +0000 2018               14                   4
# 152  Mon Dec 17 15:05:44 +0000 2018                0                  20
# 153  Mon Dec 17 14:37:00 +0000 2018                0                  20
# 154  Mon Dec 17 14:05:47 +0000 2018                0                 168
# 155  Sun Dec 16 15:01:20 +0000 2018                0                  10
# 156  Wed Dec 12 03:56:19 +0000 2018               16                   3
# 157  Sat Dec 01 15:24:51 +0000 2018               20                   4
# 158  Wed Nov 21 04:08:34 +0000 2018               11                  10
# 159  Tue Nov 20 09:05:09 +0000 2018                0                  10
# 160  Mon Nov 19 10:23:49 +0000 2018                2                   4
# 161  Mon Nov 05 19:33:31 +0000 2018                7                   2
# 162  Fri Nov 02 04:31:26 +0000 2018                4                   3
# 163  Fri Nov 02 04:08:47 +0000 2018                0                  40
# 164  Thu Nov 01 03:20:32 +0000 2018                0                   2
# 165  Wed Oct 31 04:49:32 +0000 2018                0                   0
# 166  Mon Oct 29 08:47:07 +0000 2018                9                   4
# 167  Sun Oct 28 03:25:51 +0000 2018                1                   0
# 168  Sun Oct 28 02:48:34 +0000 2018               14                   4
# 169  Wed Oct 24 11:41:59 +0000 2018                4                   0
# 170  Wed Oct 24 11:39:32 +0000 2018                1                   0
# 171  Mon Oct 22 03:54:29 +0000 2018                0                   2
# 172  Wed Oct 17 09:07:33 +0000 2018                4                   0
# 173  Wed Oct 17 07:10:25 +0000 2018                0                   0
# 174  Wed Oct 17 07:09:47 +0000 2018                0                  45
# 175  Wed Oct 17 07:08:59 +0000 2018                0                   0
# 176  Wed Oct 17 07:07:43 +0000 2018                0                  16
# 177  Tue Oct 16 17:45:30 +0000 2018                0                   0
# 178  Tue Oct 16 03:44:19 +0000 2018                0                   2
# 179  Mon Oct 15 11:09:59 +0000 2018                0                   2
# 180  Mon Oct 15 11:09:53 +0000 2018                0                   0
# 181  Sat Oct 13 13:50:07 +0000 2018                5                   2
# 182  Fri Oct 12 17:50:10 +0000 2018                5                   1
# 183  Fri Oct 12 03:48:01 +0000 2018                0                   2
# 184  Fri Oct 12 03:37:46 +0000 2018               10                   3
# 185  Wed Oct 10 17:56:45 +0000 2018                7                   1
# 186  Tue Oct 09 17:25:48 +0000 2018               13                   3
# 187  Sat Oct 06 15:22:39 +0000 2018                0                   1
# 188  Sun Sep 30 07:22:30 +0000 2018                0                 576
# 189  Sun Sep 30 07:20:56 +0000 2018                0                  47
# 190  Fri Sep 28 21:36:34 +0000 2018                0                   1
# 191  Fri Sep 28 21:17:16 +0000 2018                0                   1
# 192  Sat Sep 22 20:53:27 +0000 2018                4                   1
# 193  Wed Sep 12 09:48:48 +0000 2018                0                   2
# 194  Mon Sep 10 17:46:41 +0000 2018                0                   2
# 195  Mon Sep 10 05:37:01 +0000 2018                0                   3
# 196  Sun Sep 09 05:14:58 +0000 2018                0                   2
# 197  Thu Sep 06 09:59:01 +0000 2018                1                   0
# 198  Thu Sep 06 05:08:53 +0000 2018                0                   4
# 199  Wed Sep 05 18:05:33 +0000 2018                0                  11
# 200  Wed Sep 05 17:14:12 +0000 2018                0                   1
# 201  Tue Sep 04 18:22:18 +0000 2018                0                 688
# 202  Tue Sep 04 16:19:56 +0000 2018                5                   1
# 203  Tue Sep 04 16:16:37 +0000 2018                3                   1
# 204  Tue Sep 04 15:54:18 +0000 2018                0                  34
# 205  Tue Sep 04 01:10:31 +0000 2018                0                  28
# 206  Mon Sep 03 13:14:52 +0000 2018                0                   3
# 207  Sat Sep 01 17:25:56 +0000 2018                0                  33
# 208  Sat Sep 01 14:55:48 +0000 2018                0                  25
# 209  Sat Sep 01 03:09:52 +0000 2018                1                   0
# 210  Sat Sep 01 03:07:55 +0000 2018                0                   9
# 211  Fri Aug 31 17:50:25 +0000 2018                0                  21
# 212  Fri Aug 31 05:28:31 +0000 2018                3                   3
# 213  Fri Aug 31 03:23:10 +0000 2018                0                 196
# 214  Thu Aug 30 09:31:43 +0000 2018                0                   1
# 215  Thu Aug 30 09:28:48 +0000 2018                0                   0
# 216  Thu Aug 30 09:20:55 +0000 2018                0                 468
# 217  Thu Aug 30 04:32:16 +0000 2018                0                   2
# 218  Wed Aug 29 15:27:21 +0000 2018                0                   5
# 219  Wed Aug 29 08:25:05 +0000 2018                0                   1
# 220  Tue Aug 28 17:27:03 +0000 2018                1                   0
# 221  Tue Aug 28 17:24:55 +0000 2018                0                   1
# 222  Tue Aug 28 14:17:19 +0000 2018                0                   2
# 223  Tue Aug 28 13:56:15 +0000 2018                7                   0
# 224  Sun Aug 26 17:13:49 +0000 2018                0                   1
# 225  Sat Aug 25 05:05:20 +0000 2018                2                   1
# 226  Fri Aug 24 04:59:43 +0000 2018                0                  32
# 227  Fri Aug 24 04:59:16 +0000 2018                0                8447
# 228  Thu Aug 23 17:28:15 +0000 2018                0                  77
# 229  Thu Aug 23 15:56:47 +0000 2018                0                  83
# 230  Thu Aug 23 14:48:45 +0000 2018                6                   1
# 231  Thu Aug 23 09:01:29 +0000 2018                7                   2
# 232  Thu Aug 23 07:19:47 +0000 2018                8                   1
# 233  Thu Aug 23 07:17:40 +0000 2018                8                   3
# 234  Thu Aug 23 03:38:51 +0000 2018                2                   1
# 235  Thu Aug 23 03:34:39 +0000 2018                4                   2
# 236  Thu Aug 23 03:31:55 +0000 2018                1                   0
# 237  Wed Aug 22 19:22:16 +0000 2018                1                   0
# 238  Wed Aug 22 16:11:43 +0000 2018                0                  33
# 239  Wed Aug 22 15:50:12 +0000 2018                0                 233
# 240  Wed Aug 22 12:53:38 +0000 2018                4                   1
# 241  Wed Aug 22 05:35:37 +0000 2018                0                  61
# 242  Wed Aug 22 04:56:37 +0000 2018                0                 497
# 243  Wed Aug 22 04:56:22 +0000 2018                0                  87
# 244  Wed Aug 22 04:56:17 +0000 2018                0                 552
# 245  Mon Aug 20 05:41:16 +0000 2018                0                   1
# 246  Mon Aug 20 04:32:09 +0000 2018                3                   1
# 247  Mon Aug 20 03:51:43 +0000 2018                0                   1
# 248  Sun Aug 19 09:19:12 +0000 2018                9                   0
# 249  Sat Aug 18 19:04:18 +0000 2018                0                   3
# 250  Sat Aug 18 17:19:21 +0000 2018                0                   3
# 251  Sat Aug 18 03:55:34 +0000 2018                0                   5
# 252  Thu Aug 16 06:13:04 +0000 2018                0                  12
# 253  Thu Aug 16 04:30:12 +0000 2018                7                   3
# 254  Wed Aug 15 14:38:37 +0000 2018                0                   1
# 255  Wed Aug 15 14:37:22 +0000 2018                0                   6
# 256  Wed Aug 15 14:36:08 +0000 2018                0                   6
# 257  Wed Aug 15 09:03:25 +0000 2018                0                   4
# 258  Mon Aug 13 10:48:07 +0000 2018                0                  28
# 259  Sun Aug 12 15:07:30 +0000 2018                3                   1
# 260  Sun Aug 12 14:19:37 +0000 2018                0                  45
# 261  Sun Aug 12 13:11:04 +0000 2018                0                   2
# 262  Sun Aug 12 09:07:16 +0000 2018                0                   2
# 263  Sun Aug 12 04:29:38 +0000 2018                2                   0
# 264  Sat Aug 11 08:48:40 +0000 2018                1                   0
# 265  Thu Aug 09 10:17:53 +0000 2018                0                 111
# 266  Thu Aug 09 05:59:57 +0000 2018                0                 265
# 267  Wed Aug 08 11:30:56 +0000 2018                2                   1
# 268  Wed Aug 08 05:53:48 +0000 2018                3                   1
# 269  Wed Aug 08 05:45:58 +0000 2018                0                   1
# 270  Tue Aug 07 07:16:33 +0000 2018                0                  40
# 271  Tue Aug 07 02:05:12 +0000 2018                1                   1
# 272  Tue Aug 07 01:58:49 +0000 2018                1                   1
# 273  Tue Aug 07 01:50:33 +0000 2018                1                   1
# 274  Mon Aug 06 17:48:23 +0000 2018                0                   0
# 275  Mon Aug 06 17:46:59 +0000 2018                0                 103
# 276  Mon Aug 06 06:06:47 +0000 2018                0                   0
# 277  Fri Aug 03 05:56:33 +0000 2018                6                   1
# 278  Wed Aug 01 11:47:15 +0000 2018                5                   1
# 279  Wed Aug 01 11:20:07 +0000 2018                0                   4
# 280  Wed Aug 01 05:06:47 +0000 2018                0                   4
# 281  Tue Jul 31 12:11:52 +0000 2018                1                   0
# 282  Tue Jul 31 02:06:26 +0000 2018                0                 264
# 283  Mon Jul 30 07:30:51 +0000 2018                0                   2
# 284  Sat Jul 28 11:07:11 +0000 2018                0                  57
# 285  Sat Jul 28 06:14:09 +0000 2018                0                 105
# 286  Sat Jul 28 06:13:48 +0000 2018                0                   7
# 287  Sat Jul 28 04:08:21 +0000 2018                0                   6
# 288  Fri Jul 27 06:46:44 +0000 2018                3                   2
# 289  Fri Jul 27 04:07:31 +0000 2018                8                   2
# 290  Wed Jul 25 05:14:35 +0000 2018                5                   1
# 291  Tue Jul 24 10:33:23 +0000 2018                2                   1
# 292  Tue Jul 24 10:12:34 +0000 2018                2                   1
# 293  Tue Jul 24 09:46:26 +0000 2018                4                   1
# 294  Mon Jul 23 16:25:05 +0000 2018                3                   1
# 295  Mon Jul 23 12:53:15 +0000 2018                7                   4
#
#     Number of Images
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
# 5               None
# 6               None
# 7               None
# 8               None
# 9                  1
# 10              None
# 11              None
# 12                 1
# 13              None
# 14              None
# 15              None
# 16              None
# 17              None
# 18              None
# 19              None
# 20              None
# 21                 1
# 22              None
# 23              None
# 24                 3
# 25              None
# 26              None
# 27              None
# 28              None
# 29                 1
# 30              None
# 31              None
# 32              None
# 33              None
# 34              None
# 35              None
# 36              None
# 37              None
# 38              None
# 39                 1
# 40                 2
# 41              None
# 42              None
# 43              None
# 44              None
# 45              None
# 46              None
# 47              None
# 48              None
# 49              None
# 50              None
# 51              None
# 52              None
# 53                 1
# 54                 1
# 55              None
# 56                 1
# 57              None
# 58              None
# 59              None
# 60              None
# 61              None
# 62              None
# 63              None
# 64              None
# 65              None
# 66              None
# 67                 1
# 68              None
# 69              None
# 70                 4
# 71              None
# 72                 1
# 73              None
# 74              None
# 75              None
# 76              None
# 77              None
# 78              None
# 79                 1
# 80                 1
# 81              None
# 82              None
# 83              None
# 84              None
# 85              None
# 86              None
# 87                 1
# 88                 2
# 89              None
# 90              None
# 91              None
# 92              None
# 93              None
# 94              None
# 95                 1
# 96              None
# 97              None
# 98              None
# 99              None
# 100             None
# 101                3
# 102                4
# 103             None
# 104             None
# 105             None
# 106             None
# 107             None
# 108             None
# 109                1
# 110             None
# 111             None
# 112             None
# 113             None
# 114             None
# 115                2
# 116             None
# 117             None
# 118             None
# 119             None
# 120             None
# 121             None
# 122             None
# 123             None
# 124             None
# 125             None
# 126             None
# 127             None
# 128             None
# 129             None
# 130             None
# 131             None
# 132                1
# 133             None
# 134             None
# 135             None
# 136             None
# 137                1
# 138             None
# 139             None
# 140             None
# 141             None
# 142             None
# 143             None
# 144                1
# 145             None
# 146             None
# 147             None
# 148             None
# 149             None
# 150             None
# 151                2
# 152             None
# 153             None
# 154             None
# 155             None
# 156                1
# 157                2
# 158                3
# 159                1
# 160             None
# 161                4
# 162             None
# 163             None
# 164             None
# 165             None
# 166             None
# 167             None
# 168             None
# 169             None
# 170             None
# 171             None
# 172             None
# 173             None
# 174             None
# 175             None
# 176             None
# 177             None
# 178             None
# 179             None
# 180             None
# 181             None
# 182             None
# 183             None
# 184             None
# 185             None
# 186                1
# 187             None
# 188             None
# 189             None
# 190             None
# 191             None
# 192             None
# 193             None
# 194             None
# 195             None
# 196             None
# 197             None
# 198             None
# 199             None
# 200             None
# 201             None
# 202             None
# 203             None
# 204             None
# 205             None
# 206             None
# 207             None
# 208                1
# 209             None
# 210             None
# 211             None
# 212             None
# 213             None
# 214             None
# 215             None
# 216             None
# 217             None
# 218                1
# 219             None
# 220             None
# 221             None
# 222             None
# 223             None
# 224             None
# 225             None
# 226             None
# 227             None
# 228             None
# 229             None
# 230             None
# 231             None
# 232                1
# 233             None
# 234             None
# 235             None
# 236             None
# 237             None
# 238             None
# 239             None
# 240             None
# 241             None
# 242             None
# 243             None
# 244             None
# 245             None
# 246             None
# 247             None
# 248             None
# 249                1
# 250             None
# 251             None
# 252                1
# 253             None
# 254             None
# 255             None
# 256             None
# 257             None
# 258             None
# 259             None
# 260             None
# 261             None
# 262             None
# 263             None
# 264             None
# 265                1
# 266             None
# 267             None
# 268                1
# 269             None
# 270                1
# 271             None
# 272             None
# 273             None
# 274             None
# 275                1
# 276             None
# 277             None
# 278                1
# 279             None
# 280             None
# 281             None
# 282             None
# 283             None
# 284             None
# 285             None
# 286             None
# 287             None
# 288             None
# 289             None
# 290             None
# 291             None
# 292             None
# 293                1
# 294             None
# 295             None
